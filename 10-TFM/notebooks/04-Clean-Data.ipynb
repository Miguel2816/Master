# %% [markdown]
# # TFM Máster Data Science UAH 2020-2021
#
# ### MIGUEL PÉREZ CARO
#
# Este notebook tiene como objetivo limpiar el dataset para que pueda ser usado posteriormente. Tratamiento del texto:
#
# - Convertir a minúsculas
# - Eliminar stopwords
# - Eliminar signos de puntuación y símbolos extraños
# - Eliminar links
# - Tratar los espacios
# - Eliminar otro tipo de palabras frecuentes que no aporten valor.
#
# En primer lugar se importan las librerías.

# %%
import os
import re
import string
import numpy as np
import pandas as pd
import seaborn as sns
from nltk.corpus import stopwords
from emot.emo_unicode import EMOTICONS_EMO, UNICODE_EMOJI

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Se establece el directorio de trabajo.

# %%
directorio = os.path.dirname(os.getcwd())
mydir = os.path.join(directorio, 'data')
os.chdir(mydir)

# %% [markdown]
# Se carga el archivo

# %%
df_raw = pd.read_csv('df_raw.csv')

# %% [markdown]
# Se modifica el tipo de los datos

# %%
df_raw['id'] = pd.to_numeric(df_raw['id'], errors = 'coerce')
df_raw.dropna(inplace=True)
df_raw['created_at'] = df_raw['created_at'].astype('datetime64[ns]')
df_raw['retweet_count'] = df_raw['retweet_count'].astype('float64')

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 566643 entries, 0 to 566650
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              566643 non-null  float64
#  1   created_at      566643 non-null  datetime64[ns]
#  2   text            566643 non-null  object
#  3   retweet_count   566643 non-null  float64
#  4   favorite_count  566643 non-null  float64
#  5   southwest       566643 non-null  float64
#  6   american        566643 non-null  float64
#  7   united          566643 non-null  float64
#  8   delta           566643 non-null  float64
# dtypes: datetime64[ns](1), float64(7), object(1)
# memory usage: 43.2+ MB

# %% [markdown]
# Se analizan los textos duplicados:

# %%
df_raw['text'].duplicated().sum()
# Out:
# 239650

# %% [markdown]
# Se eliminan los textos duplicados en base a las conclusiones obtenidas en el notebook 03-Analyze-Data. Para ello se hace uso de la función groupby

# %%
df_raw_no_dup = df_raw.groupby('text').agg({'id': 'first', 
                                            'created_at':'first', 
                                            'retweet_count':'max',
                                            'favorite_count': 'max',
                                            'southwest': 'max',
                                            'american': 'max',
                                            'united': 'max',
                                            'delta': 'max'}).reset_index()

# %% [markdown]
# Se comprueba el resultado

# %%
df_raw_no_dup['text'].duplicated().sum()
# Out:
# 0

# %%
df_raw_no_dup.shape
# Out:
# (326993, 9)

# %% [markdown]
# Se convierte el id a un string

# %%
df_raw_no_dup['id'] = df_raw_no_dup['id'].astype('object')

# %%
df_raw_no_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326993 entries, 0 to 326992
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   text            326993 non-null  object
#  1   id              326993 non-null  object
#  2   created_at      326993 non-null  datetime64[ns]
#  3   retweet_count   326993 non-null  float64
#  4   favorite_count  326993 non-null  float64
#  5   southwest       326993 non-null  float64
#  6   american        326993 non-null  float64
#  7   united          326993 non-null  float64
#  8   delta           326993 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 22.5+ MB

# %%
df_raw_no_dup.shape
# Out:
# (326993, 9)

# %% [markdown]
# Se genera un csv sin limpiar pero sin texto duplicado.

# %%
df_raw_no_dup.to_csv("df_raw_no_dup.csv", sep = ',', index=False, 
              columns = ['id','created_at','text','retweet_count','favorite_count', 
                         'southwest', 'american', 'united', 'delta'])

# %% [markdown]
# Para comenzar con la limpieza, se van a generar en primer lugar dos funciones para la limpieza de los emojis y los emoticonos, para continuar con otra función que incluir'a una limpieza más general y llamar'a a estas dos funciones.

# %%
def clean_emoticons(text):
    """
    Función generada para hacer la limpieza de emoticonos.
    
    param: text texto a limpiar
    :return: texto limpio
    """
    for emot in EMOTICONS_EMO:
        if emot in text:
            text = text.replace(emot, " {} ".format(EMOTICONS_EMO[emot]))
    return text

# %%
def clean_emojis(text):
    """
    Función generada para hacer la limpieza de emojis.
    
    param: text texto a limpiar
    :return: texto limpio
    """
    for emot in UNICODE_EMOJI:
        if emot in text:
            text = text.replace(emot, " {} ".format(UNICODE_EMOJI[emot].replace(':',"").replace('_',' ')))
    return text

# %% [markdown]
# Se procede ahora con la limpieza para el análisis de sentimiento. Para ello, se crea una función que realiza lo siguiente:
#
# - Eliminar los usuarios. No aportan información al  análisis de sentimiento que se pretende hacer posteriormente.
# - Eliminar los enlaces web.
# - Convertir todo el texto a minúsculas.
# - Eliminar los emojis y emoticonos. Importante que se eliminen tras la limpieza de los enlaces web ya que estos pueden incluir secuencias de carácteres idénticas a algún emoticono, lo que conllevaría que se preprocesaría como si fuera un emoticono aunque fuera parte de un enlace web.
# - Eliminar los signos de almohadilla, ya que el hashtag si que puede contener información. Eliminar la palabra rt, que no aporta valor y aparece con frecuencia.
# - Eliminar los nombres de las aerolíneas que se usaron para la búsqueda ya que tampoco aporta ningún valor al análisis de sentimiento y ya está recogida su presencia en el texto. En estos se incluyen también acrónimos, y las siglas de los números de vuelo. Por ejemplo un vuelo de American Airlines podría ser el AA123, que tras la limpieza resultaría en aa, que no aporta ningún valor.
# - Eliminar las abreviaturas usadas para situar a los aviones en vuelo, ya que tampoco aportan valor al texto. En estos casos se incluyen términos como mi, para describir las millas, ft, que son los pies de altura, o frm y hrzn para situar las coordenadas del avión.
# - Eliminar lo que no sea minúscula o espacio.
# - Normalizar espacios.
# - Eliminar stopwords.

# %%
lista_elementos_eliminar = ['#', ' rt ', '\n', 'american airlines', 'delta airlines', 'united airlines', 
                            'southwest airlines', ' aa ', ' aal ', ' dl ', ' dal ', ' ua ', ' ual ', ' swa ',
                            ' mi ', ' ft ', ' frm ', ' hrzn ', ' amp ', ' aaa ']

# %%
def cleaning_text_basico(df, lista_elementos_eliminar):
    """
    Función generada para hacer una limpieza general del texto.
    
    param: df dataframe a limpiar
    :return: lista con el texto limpiado. Un elemento por cada fila del dataframe.
    """
    corpus = [' ' + text + ' ' for text in  df.text.tolist()] # Añadir espacio al principio y al final apra fcilitar limpieza
    corpus = [re.sub('@[A-Za-z0-9_]+',' ', text) for text in corpus] # Eliminar usuarios
    corpus = [re.sub(r'http\S+', '', text) for text in corpus] # Eliminas enlaces web
    corpus = [text.lower() for text in corpus] # Pasar a minúsculas
    #corpus = [clean_emojis(text) for text in corpus] # Eliminar emojis
    #corpus = [clean_emoticons(text) for text in corpus] # Eliminar emoticonos
    #corpus = [''.join(ch for ch in text if ch not in string.punctuation) for text in corpus] # Eliminar signos de puntuación
    corpus = [re.sub(r'[^a-z\s]', '', text) for text in corpus] # Eliminar lo que no sea minúscula o espacio
    for i in lista_elementos_eliminar:
        corpus = [re.sub(i,' ', text) for text in corpus] # Eliminar elementos de la lista
    corpus = [text.strip() for text in corpus] # Normalizar espacios
    corpus = [re.sub(r' +', ' ', text) for text in corpus] # Normalizar espacios
    corpus = [' '.join(word for word in text.split() if word not in stopwords.words('english')) for text in corpus] # Eliminar stopwords 
    return corpus

# %%
corpus_clean = cleaning_text_basico(df_raw_no_dup, lista_elementos_eliminar)

# %%
corpus_clean
# Out:
# ['cancelled one leg trip eu sent email telling call called multip',
#  'im told cannot redeem travel certificate expired middle global pandemi',
#  'update still dfw good morning everyone except',
#  'attention new million mile flyer alert congrats mr david white achieving one million miles',
#  'american delta immediate plans covid vaccine mandates',
#  'formerly gonna go well',
#  'brands like dennys using college football stars nil era',
#  'deltaairlines executives said pair memos employees thursday airlines permanent noflylist',
#  'deltaairlines major us airline without vaccinemandate employees',
#  'newswire adds daily austin flight expanded service rick husband amarillo international ai',
#  'social networking news making sure cant escape tiktok news',
#  'social networking news making sure cant escape tiktok news',
#  'travel news ramps domestic schedule flights since pandemic began expecting',
#  'worldnews story doj challenge jetblue partnership news',
#  'worldnews story southwest american rejecting employee vaccine mandates news',
#  'worldnews story require employees vaccinated news',
#  'please remember designated items onboard may used difficult situations alternative',
#  'says require employees fully vaccinated covid approved',
#  'weekly roundup latest cyber security news trends indicators attackers actively exploit micr',
#  'seismographic recordings picked ground movement miles north tower seconds earlier',
#  'theyve got great data science tell us want us check everyone prepared',
#  'paying teams use including companies like cbre intel kimberlyc',
#  'footprint jet fuel customers see actual waste cups plastic partner socially sustaina',
#  'said american forced pilots work days offcrew members even forced skip meal',
#  'joined air carriers encouraging unvaccinated employees get shot offering',
#  'air lines recently announced penalty unvaccinated workers already encouraged onefifth th',
#  'wednesday introduced new incentives get staff vaccinated covid following similar p',
#  'content licensed directly free passengers case study bestinclass',
#  'airlines said wednesday usbased employees fully vaccinated',
#  'fires employees complying covid vaccine mandate im waiting day',
#  'announces health integration verifiable covid vaccination records sharing smart health c',
#  'denverbased employee fears could lose job even though hes received religious exemptio',
#  'flight attendant died covid shepperson fully vaccinated covid vacci',
#  'list banned customers doesnt work well customer fly another airline kristen manion tay',
#  'list banned customers doesnt work well customer fly another airline kristen manion tay',
#  'list banned customers doesnt work well customer fly another airline',
#  'lot personal connection nearly every month pilot flew right seat boeing flight',
#  'passenger flight landed miami international airport opened emergency door',
#  'picture equity says leadership look like front line read says workforce',
#  'surge coronavirus caseloads across nation starting dampen enthusiasm leisure travelers',
#  'americans mainline schedule cancelled spirits according',
#  'according indeed leading job posting website job postings require vaccinations large corporat',
#  'according privacy policies cos orgs commons project fdn healthcare data',
#  'according society human resource management less people say would rather leave',
#  'according complaint unprecedented combination would raise prices reduce choices air passenger',
#  'adventures denver atlanta kidding lets go nashville ran fuel',
#  'airlines warn major disruptions g cband major disruptions passenger air travel commercial tra',
#  'major us airlines delta employee vaccine mandate know wont flying',
#  'servers also running freebsd anyone could administer server like southwest',
#  'overhead bins full check bag get seat bin row comp',
#  'ceo doug parker woke denounced new texas voting law likewise requiring tougher',
#  'ceo says biden admin require proof covid vaccination domestic travel video',
#  'claims didnt know yearold kicked plan asthma despite mom administeri',
#  'adds tiktok free inflight entertainment pretty smart neat partnership',
#  'jetblue face antitrust suit alliance justice department said partnership amo',
#  'jetblue face antitrust suit alliance justice department said partnership amo',
#  'jetblue face antitrust suit alliance justice department said partnership amo',
#  'jetblue face antitrust suit alliance',
#  'jetblue face antitrust suit alliance peter eavis via nyt',
#  'jetblue face antitrust suit alliance peter eavis via nyt',
#  'jetblue face antitrust suit alliance pharma',
#  'jetblue sued doj airline alliance cnn cheaters keep prices high',
#  'jetsmart sign letter intent create broadest rewarding network amer',
#  'drops american way magazine joins southwest delta didnt know going',
#  'passenger detained allegedly opening emergency exit walking wing via fox news',
#  'passenger detained allegedly opening emergency exit walking wing',
#  'pilots union strike fatigue overscheduling',
#  'pilots union strike fatigue overscheduling posted nagendra bandi',
#  'pilots union strike fatigue overscheduling via fox finance business news',
#  'pilots union strike fatigue overscheduling via fox biz backbonefinancial',
#  'pilots union strike fatigue overscheduling via fox biz',
#  'pilots union strike fatigue overscheduling september reuters labor',
#  'said would flying empty flights los angeles sydney next two months',
#  'staff duct tape yearold boy seat viral video',
#  'told pilots conserve jet fuel supply possible memo monday saying transport',
#  'let watch minutes tiktok air free opens obvious question ot',
#  'begin serving alcohol main cabin flights least january',
#  'wont serve alcohol coach coach lmaooooooooooo fucking poors dont kno',
#  'arcelormittal bank america blackrock boston consulting group gm microsoft colle',
#  'microsoft join gatesbacked program boost clean energy september reuters se',
#  'let clear majority im coming knocking door',
#  'pinned blame weekend storm hit dallas fort worth international airport larg',
#  'word delta word give travel discount dont really',
#  'president cited example several large companies already require employees vaccinated',
#  'mask exhaust valve approved acceptable face mask customers traveling delta ope',
#  'anyone doesnt know wear mask flights stay home disney world',
#  'aquarium getting harder wake morning coffee exercise please youre aqua',
#  'sure saw mouse boeing nua little problem los angeles',
#  'sure saw mouse boeing nua little problem los angeles',
#  'covid continues surge accelerated delta variant several european governments companies ban',
#  'herb kelleher succinctly put strategy overdone stuff underdone carlo',
#  'large swaths officeworker community went remote covid showed could work many want',
#  'large swaths officeworker community went remote covid showed could work many want',
#  'someone studied history airports united states someone old enough remember air',
#  'end day want win todays player spotlight sjvlafc',
#  'atrocities committed conflict also appear violate terms trade program provides lucrati',
#  'atrocities committed conflict also appear violate terms trade program provides lucrati',
#  'atrocities committed conflict also appear violate terms trade program provides lucrati',
#  'atrocities committed conflict also appear violate terms trade program provides lucrati',
#  'atrocities committed conflict also appear violate terms trade program provides lucrati',
#  'aviate max boeing max turns active runway begins taxi toward boeing plaz',
#  'azorra delivers second six es',
#  'bastian noted average hospital stay covid cost company per person surcharg',
#  'international flight mdpd still working lead agency case',
#  'alliance delta united dominated new york city market american air ceo yea isnt',
#  'dad airlines dont duct tape unruly passengers says',
#  'days many smartphoneequipped amateur reporters chronicled lot peoplemostly conservative',
#  'midafternoon spirit scrapped half scheduled flights day according flightaware',
#  'covid hurting business announced also require employees vaccinated added',
#  'covid response info masks staff covidiots covidisnotover',
#  'caitrona balfe judi dench jamie dornan star gala kenneth branaghs belfast belfa',
#  'california new york hours timetable george foster timetable collection',
#  'call hp call dell call move em virginia mcauliffe said listing major companies',
#  'call hp call dell call move em virginia mcauliffe said listing major companies',
#  'carl go hell',
#  'carriers including alaska air group alk american delta united trimmed fall schedules inde',
#  'chattanooga tennessee mayor tim kelly announced vax cash sweepstakes weekly drawing open',
#  'chuck norris packs nuts kingbibi blabla',
#  'come celebrate small businesses us continue buy food restaurants ideally capital one credi',
#  'companies full shit alex screw stew needs fired immediately',
#  'conserve wasting fuel also isnt normalare ppl ready admit current admini',
#  'corrupt lenin moreno fled yesterday flight pm miami offered work fiu u',
#  'coverage leftrated sources often framed businesses ready willing comply mandate highligh',
#  'delta air lines require employees vaccinated pay health insurance surcharge unusual',
#  'delta air lines soon raise unvaccinated employees insurance premium per month sick vi',
#  'stop messing itinerary challenge want get home without worry anoth',
#  'delta plus trending isnt airlines new frequent flier program',
#  'delta plusi must wrong page thought new frequent flyer milage program offered',
#  'delta require new us hires including flight attendants pilots vaccinated',
#  'delta united already require new hires vaccinated major us airlines including american',
#  'delta name people meant fly social commun',
#  'delta stopped short mandatory vaccine requirement like one imposed earlier month',
#  'delta wants share bannedpassenger lists among airlines experts say isnt easy',
#  'delta wants share bannedpassenger lists among airlines experts say isnt easy',
#  'delta wants share bannedpassenger lists among airlines experts say isnt easy',
#  'delta wants share bannedpassenger lists among airlines experts say isnt easy',
#  'delta wants share bannedpassenger lists among airlines experts say isnt easy',
#  'delta wants share bannedpassenger lists among airlines experts say isnt easy',
#  'delta wants share bannedpassenger lists among airlines experts say isnt easy',
#  'delta wants share bannedpassenger lists among airlines experts say isnt easy',
#  'delta wants share bannedpassenger lists among airlines experts say isnt easy',
#  'delta wants share bannedpassenger lists among airlines experts say isnt easy',
#  'delta wants share bannedpassenger lists among airlines experts say isnt easy',
#  'delta wants share bannedpassenger lists among airlines experts say isnt easy',
#  'delta wants share bannedpassenger lists among airlines experts say isnt easy',
#  'delta wants share bannedpassenger lists among airlines experts say isnt easy',
#  'delta american providing african migrants free flights us dont care',
#  'delta amtrak wings late night david letterman top new advertising slogans delta airlin',
#  'disgusted amir khan rants airline escorted plane us',
#  'disgusted amir khan rants airline escorted plane us',
#  'disgusted amir khan rants airline escorted plane us',
#  'disruptive behavior using creative adjective huh disappointing',
#  'ducttape passengers tells flight attendants memo airports bad behavior rgv flyers',
#  'dont worry antivax employees youve got good chance getting something delta',
#  'dont duct tape unruly passengers says memo employees oh cmon one',
#  'dont worry cancel book worse flight one bought money initially spent',
#  'dont worry well take care thats ticket agent san gate said arriv',
#  'douglas parker clarifies airline company would still obey bidens mandate order given says wouldnt',
#  'employees fired getting vaccinated would terminated grounds violating company safety policy',
#  'employees suing mandatory vaccines business next read',
#  'employees receive religious exemptions put voluntary unpaid leave receive medical exempt',
#  'ethiopias government used countrys flagship commercial airline shuttle weapons neighborin',
#  'ethiopian airlines undoubtedly sent thousands soldiers locations near fighting tigray',
#  'even though denied allegations eyewitnesses pictures identified soldiers boarding co',
#  'f mr f figure tiktok linkedin normally become airline pilots right wonde',
#  'fbi pacific flight part',
#  'fingers crossed end long period airlines singling cyclists cash grab',
#  'flight attendant pilot labor unions raised alarms unruly passenger behavior thats surged th',
#  'fly friendly skies andanother passenger gets ducttaped seat',
#  'fly friendly skies',
#  'flying kyle hendricks presented boring thing ever promoted ballpark',
#  'following mandate says us employees fully vaccinated business investor',
#  'instance include airfare purchased headquartered fort worth f',
#  'fact people times likely die theyre unvaccinated need know',
#  'several days june temperatures sky harbor international airport phoenix high american airli',
#  'ninth year row jet blue ranked first satisfaction among north ranked las',
#  'record relation dont know sincerely',
#  'free flights act check',
#  'cornermost window spot stationary glow domestic terminal mile away sfo united airline',
#  'given today delta variant united states maintain existing travel restrictions',
#  'god intend us foil laws nature vaccine proceeds fly sky metal',
#  'great advertising wears create brand design philosophy works drive',
#  'guard cockpits aircraft ret ltc joe lea joins tango alpha lima podcast discus',
#  'hello please upgrade seat know said window seat ridiculous',
#  'helping blackowned business priority via',
#  'helping blackowned business priority',
#  'heres email exec council chairman todd insler sent back pilot asked hu',
#  'hewlettpackard enterprise moving global headquarters houston area headquarte',
#  'hi tickets booked months ago get best rates got moved messed schedule',
#  'hidden feesno way hidden covid absolutely flight attendants may may vaccinatedwe dont gi',
#  'google walmart amtrak others addressing covid vaccines read',
#  'partnered money team backing',
#  'hope every airline country done requiring employees vaccinated h',
#  'dropped floor started crying said tiktoker eventually reunited pets',
#  'mad could take away got older mom explained',
#  'learned compare others says technician yolanda gong dont mistake opinions fac',
#  'love god govt lets corporate funders overrule constrights dad seniority pilot jal mom usss yrs honore',
#  'propose adopt convention naming new variant covid airline fair special ha',
#  'sued cause sold ticket new jersey went sucked still favor',
#  'suggest flying spirit airport manager shuts karen called employee b',
#  'tell everybody dont take spirit never take spirit said omed walybek flight los angeles',
#  'think administrations really admirable job trying find levers push get whol',
#  'turned around told im child need mind business didnt know worked',
#  'want steer clear group southwest says',
#  'years old watched live tv classroom flight slammed',
#  'write grave concerns recent joint partnership jetblue airways l',
#  'im former attendant im walking miles colleagues lost',
#  'im former attendant im walking miles colleagues lost',
#  'im aware airlines tough time seems unfair via travel finance',
#  'im disgusted would us',
#  'im tired employees dying united ceo comms say yesterday employee die',
#  'ive never seen flight attendant says stuffs napkins ceiling brown li',
#  'ive written letters families every employee lost life covid ceo scott kirby',
#  'charge wouldve blamed cancellations weather given everyone',
#  'united continues posture look cpac aggressively oppose legislative efforts dc across',
#  'survive represent must bolster advocate must submit',
#  'theyre gonna online thing site app whatever need make work better easier use',
#  'sounds like plane future isnt well got right w',
#  'choose decide still made choice',
#  'criticize peoples ideas never use want hang employees make sure th',
#  'know put phone airplane mode ask small child probably better',
#  'force us vaccinate quit cry antivaxxers reality says otherwise didnt see resi',
#  'airlines reported unruly passengers full year since began collecting data',
#  'air freight members advancing sustainability purchasing new fuel efficient aircra',
#  'announcement yesterday google said anyone coming office would need vaccinated faceboo',
#  'initial q results show net losses airlines aggregated level diminished compared q',
#  'interviews get rampagent interviews interviewing interested candidates',
#  'claims collectively bargained union instead giving force majeure',
#  'depends sector depends business want react applaud ceo scott k',
#  'hurt bad quick dawn shepperson said didnt time really even acknowle',
#  'evidence industry faces bumpy road ahead many border restrictions still place',
#  'would result higher fares fewer choices lower quality service allowed continue',
#  'phenomenal outcome mandates work ceo scott kirby uniteds employees getti',
#  'phenomenal outcome mandates work ceo scott kirby uniteds employees getti',
#  'phenomenal outcome mandates work ceo scott kirby uniteds employees getti',
#  'inspiring people serving people caring people caring people learn top lessons',
#  'jab lose ends coronavirus pandemic leave unvaccinated employees',
#  'jetblue positioned important source competition jetblues inter',
#  'jetblue blast doj lawsuit challenging northeast partnership biznews businessnews',
#  'jetblue blast doj lawsuit challenging northeast partnership',
#  'jetblue blast doj lawsuit challenging northeast partnership posted nagendra bandi jet',
#  'jetblue blast doj lawsuit challenging northeast partnership via fox biz',
#  'jetblue blast doj lawsuit challenging northeast partnership via fox biz',
#  'jetblue blast doj lawsuit challenging northeast partnership via fox',
#  'john mulaney known loving wife john mulaney known hating',
#  'ladies gentlemen airline regularly scored high equality ind',
#  'law enforcement officers asked meet flight operated regional carrier republic airways',
#  'lets go beacheach lets go get away lyrics take less starships feeling',
#  'lucas wall washington dc said medical condition means cant wear mask exem',
#  'massive cancelations yep texas astros cowboys let texastaliban wage wa',
#  'major corps claiming take action cllimatechange sustainability incl',
#  'many feel new covid variant delta plus sounds like streaming service nope thought',
#  'maurice reggie shepperson shepperson flight attendant known extreme caution g',
#  'maurice shepperson fully vaccinated flight attendant whose mother says died',
#  'mike harmon two decades experience state government lets forget private sector experienc',
#  'milesmigrants funded shapiro foundation tripadvisor foundation works ame',
#  'milesmigrants organization working delta american along uber nonprofit',
#  'milesmigrants funded shapiro foundation tripadvisor foundation works delta airline',
#  'mind way asthmatic showed flight attendant negative covid test way yesterday told',
#  'mom claims flight attendant told glue twoyearold daughters face mask',
#  'nobody goes twitter say amazing experience go say sucks',
#  'putting mandates vaccinations employees ceo doug parker tells',
#  'reschedule another airplane travel back training camp really upsetting reason',
#  'oh gosh fourhour wait something thats going take three minutes lateteen dinner dates c',
#  'omar aint terrorist ngga gun aint ngga got sht took marlo',
#  'friday said would impose vaccine mandate delta air lines southwest airlin',
#  'one southwest passenger banned airline may punching flight attendant knocking two',
#  'one found passports belonged hijacker flight passport satam al',
#  'efforts include commonpass mobile app created commons project foundation world economic',
#  'united next vision revolutionize experience flying united accelerate business meet',
#  'corporate travel month june thats march thre',
#  'name isnt even related pandemic understand avoiding corona beer',
#  'partnering nobrainer premium brand core values',
#  'passenger volumes alaska delta united clubs close equal precovid numbers according ai',
#  'pilots flight attendants said sometimes arrived airports find dont hotel',
#  'pilots union sues alleges violation federal labor law september daniel wiess',
#  'pilots flight attendants gate agents airport customer service agents interact customers gra',
#  'plane crash podcast interviews former pacific psa flight attendant san dieg',
#  'please dos dont donts even though morning fly girl come fo',
#  'please remember designated items onboard may used difficult situations alternative',
#  'please remember designated items onboard may used difficult situations designated',
#  'police detain passenger accused walking plane wing',
#  'providing excellent customer service airline industry aspects service likely challe',
#  'quadriplegic says refused load wheelchair violation federal law via fox news',
#  'quadriplegic says refused load wheelchair violation federal law via fox news',
#  'real people real results one employee ive lost pounds today first day back year',
#  'realworld evidence soon support mandates increasing health insurance costs ie every v delta ps',
#  'rediscover joy travel says video seat dead soulless voices flight attend',
#  'reggie fully vaccinated heart breaks family mask flight attend',
#  'rules create safety culture doesthat means leaders personal influence get buyin',
#  'sky express cooperation',
#  'schiffman last bookings southwest adjusted airlines parlance trips originally booked',
#  'sen blumenthal wrote letter dot friday recent revenuesharing agreement american airline',
#  'senate bill enacted signed made effective scarcely peep protest american corporations',
#  'several us companies including group inc general motors microsoft corp monday buil',
#  'earns several million dollars year mat pitching sponsors like visa athleta oreo',
#  'since announced us employees must provide proof vaccinated oct',
#  'far year agency received reports disruptive passengers according stateme',
#  'take example flight leaves dfw goes sxm flight would receive fresh food flight sxm',
#  'sometimes imitation may better innovation companies stole ideas b',
#  'made big change pilots flight attendants happy read',
#  'wins injunction barring travel site scraping airlinetickets',
#  'cuts flights fix operational challenges august chicago reuters southwest ai',
#  'plan resume onboard alcohol sales least january according memo sent',
#  'forced passenger cover probiden sign offending people',
#  'hosted hybrid thanniversary rally massive airplane hangar houston read',
#  'giving fully vaccinated staff hours extra pay cutting special sick pay fo',
#  'says delta variant hurting business',
#  'says delta variant hurting business posted nagendra bandi',
#  'says delta variant hurting business via fox finance business news',
#  'says delta variant hurting business via fox biz backbonefinancial',
#  'says delta variant hurting business via fox biz',
#  'says employees must vaccinated december azi paybarah via nyt new york times',
#  'says employees must vaccinated december azi paybarah via nyt new york times',
#  'says employees must vaccinated december azi paybarah via nyt new york times',
#  'says employees must vaccinated december azi paybarah via nyt new york times',
#  'says employees must vaccinated december azi paybarah via nyt new york times',
#  'tells mum glue mask toddlers face mother speaking incident involving',
#  'warns covid uptick hitting bookings posted nagendra bandi major us carrier disclo',
#  'take proactive steps protect employees workplace event infectious disease outbreak',
#  'southwest latest airline mandate vaccines workers biznews businessnews businesstalk southwest airlin',
#  'southwest latest airline mandate vaccines workers posted nagendra bandi monda',
#  'southwest one three airlines us requiring employees get vaccinated reported c',
#  'southwest suing skiplagged company helps people find itineraries involve twostep flight',
#  'spirit airlines cancel hundreds flights niraj chokshi',
#  'spirit airlines cancel hundreds flights niraj chokshi via nyt read',
#  'spirit airlines cancel hundreds flights niraj chokshi via nyt',
#  'spirit airlines cancel hundreds flights niraj chokshi via nyt',
#  'spirit airlines cancel hundreds flights niraj chokshi via nyt',
#  'spirit airlines cancel hundreds flights niraj chokshi via nyt',
#  'spirit airlines cancel hundreds flights niraj chokshi via nyt',
#  'spirit airlines cancel hundreds flights niraj chokshi via nyt',
#  'spirit airlines cancel hundreds flights niraj chokshi via nyt',
#  'spirit airlines cancel hundreds flights niraj chokshi via nyt',
#  'spirit airlines cancel hundreds flights via trending news',
#  'spirit airlines canceled nearly flights memorial day labor day delta canceled f',
#  'tech savvy cutting edge social media engaging industry moguls intuwit wi',
#  'tech savvy cutting edge social media engaging industry moguls intuwit winnin',
#  'thank u calling teh kahit pandemic dami nagbobook flights',
#  'thank calling hold times times longer flight',
#  'thank calling representatives currently assisting customers cu',
#  'thanks patience really lost bag hours yesterday wait hours toda',
#  'thanks airlines making spend hour walking around washington dc iad airport flight arrive',
#  'pentagon moving toward compelling major help transport tens thousands evacuees',
#  'ceos american delta said mandate covid vaccines emp',
#  'constitution protects freedom fly without mask people society become ignorant',
#  'force strong one boeing n star wars rise skywalker special liv',
#  'justice department six states file lawsuit block partnership formed americanairlines',
#  'justice department gearing file antitrust case jetblue allia',
#  'justice department set challenge partnership jetblue antitrust grounds peopl',
#  'man right chea rapper receiving hospitality sou',
#  'pentagon moving toward compelling major help transport tens thousands evacuees f',
#  'ticket man know unused ticket flight dated',
#  'us transportation department wednesday said limit flights chinese carriers passe',
#  'us airline industry divided one side hawaiian frontier requirin',
#  'worlds magical celebration reached skies yesterday unveiled newest liver',
#  'airline joins air travel companies including adopting',
#  'airline said enough workers operate schedule fall holidays yet r',
#  'best option obtaining pakistani mangoes ordering whatsapp picking least eight boxe',
#  'carnage roads stop know know called safe systems approach',
#  'carriers grappling wthe recent surge covid cases us delta variant takes hold',
#  'civil antitrust complaint alleges consolidating operations new york boston partnersh',
#  'current wait time representative hours minutes fun charged card g',
#  'data leak affected marylands health department new yorks metropolitan transpor',
#  'extension reflects impact highly transmissible delta variant acknowledgement transit',
#  'facts crystal clear everyone safer everyone vaccinated ceo scott kirby said mem',
#  'fight climate change succeed everyone comes together promote ambition coope',
#  'flew horses emirates athletes dedd',
#  'flights often assigned flight numbers primarily et et et et',
#  'goal keep passengers banned bad behavior simply switching airlines completely agree thi',
#  'hijackers played music marvin gaye stevie wonder four tops thinking would keep passengers',
#  'incident affected major companies organizations including ford jb hunt mar',
#  'man growled like dog shot middle finger flight attendants yelled god bless america joe b',
#  'measure also prevents us airlines marketing selling tickets mexican partner airlines although',
#  'thing covid done society remove people compassion sep asthma ki',
#  'pilots assert uals covid vaccine mandate places particular significant risk harm w',
#  'question case whether companycan publish information openly internet sue',
#  'system collapsing money isnt even real ihateithere airline union chief slams av',
#  'vaccines highly effective preventing infections breakthrough cases still possible sho',
#  'private right action words corporations rights bs airlines including',
#  'theres something going theyre booting people reselling tickets',
#  'emotional missions people carrying back leaving clothes back',
#  'theyre screaming punching refusing wear masks generally behaving instructed donald trump',
#  'tweet started boarding flight meeting',
#  'seems silly guess reminded pandemic change lives',
#  'flight gonna go chose get overages gate agent says matter factly',
#  'dream come true front family friends nicky helped sweep hometown team field gr',
#  'lufthansa policynothing doyou contact',
#  'largest single growth austin weve ever year history says n',
#  'largest single growth austin weve ever year history says n',
#  'third incident passengers ducttaped seats dangerous behavior commercial plan',
#  'warning states america could go way texas unless elect individuals',
#  'incredibly difficult decision keeping team safe always first priority united ai',
#  'incredibly difficult decision keeping team safe always first priority airli',
#  'week airline also said anyone refusing vaccinated religious reasons would ha',
#  'three major us airlines say force employees vaccinated posted nagendra bandi three major',
#  'throwin parties miami love us mucho naaauuuurrr bc go watch footage back walk talk live',
#  'equate asking photo id every voter throwback jim crow laws stupid face',
#  'kick sweepstakes style first winner also receive pair round trip plane tickets',
#  'try remember bushs speech people aboard flight wasnt',
#  'tsk tsk would treated year old compassion asthma attack mom filled',
#  'two months required us workers vaccinated niraj chokshi',
#  'two months required us workers vaccinated niraj chokshi',
#  'two months required us workers vaccinated niraj chokshi',
#  'two months required us workers vaccinated niraj chokshi',
#  'two months required us workers vaccinated niraj chokshi',
#  'two months required us workers vaccinated niraj chokshi',
#  'two months required us workers vaccinated niraj chokshi',
#  'two months required us workers vaccinated niraj chokshi',
#  'two months required us workers vaccinated niraj chokshi',
#  'two months required us workers vaccinated niraj chokshi',
#  'two months required us workers vaccinated niraj chokshi',
#  'two months required us workers vaccinated unknown author v',
#  'two months required us workers vaccinated unknown author v',
#  'two months required us workers vaccinated unknown author v',
#  'two months required us workers vaccinated unknown author v',
#  'two months required us workers vaccinated unknown author v',
#  'two months required us workers vaccinated unknown author v',
#  'two months required us workers vaccinated unknown author v',
#  'two months required us workers vaccinated unknown author v',
#  'two months required us workers vaccinated unknown author v',
#  'two months required us workers vaccinated unknown author v',
#  'two months required us workers vaccinated unknown author v',
#  'us sues stop deal jetblue via',
#  'uhhhhh get u jfk charleston told ass',
#  'unique logistics contracted operate around flights several airlines asia pit oth',
#  'better airline services provide accessible everyone scott kirby',
#  'ceo scott kirby requires entire global staff vaccinated read',
#  'ceo scott kirbys early decision mandate covid vaccines nearly us wo',
#  'mandates covid vaccines us employees health pharma',
#  'prepares fire employees refusing covid jab',
#  'hawaiian airlines say mandate vaccines employees one',
#  'hawaiian airlines say mandate vaccines employees',
#  'announced friday morning mandating employees get covid vaccine becoming first majo',
#  'begins firing unvaccinated workers coral murphy marcos via nyt new york times',
#  'begins firing unvaccinated workers coral murphy marcos via nyt new york times',
#  'begins firing unvaccinated workers coral murphy marcos via nyt new york times',
#  'begins firing unvaccinated workers coral murphy marcos via nyt new york times',
#  'begins firing unvaccinated workers coral murphy marcos via nyt new york times',
#  'begins firing unvaccinated workers coral murphy marcos via nyt new york times',
#  'begins firing unvaccinated workers coral murphy marcos via nyt new york times',
#  'begins firing unvaccinated workers coral murphy marcos via nyt new york times',
#  'begins firing unvaccinated workers coral murphy marcos via nyt new york times',
#  'begins firing unvaccinated workers coral murphy marcos via nyt new york times',
#  'begins firing unvaccinated workers coral murphy marcos via nyt new york times',
#  'begins move fire workers refused covid vaccine cnet news feedly',
#  'cuts number workers facing termination vaccine noncompliance october chicago',
#  'ditches cargoonly flights passengers return',
#  'urging flight crews avoid using ducttape restrain passengers amid uptick incid',
#  'pilots gear fullsized commercial flight show bayarea nat',
#  'staff granted religious exemptions vaccine mandate put unpaid leave',
#  'staff granted religious exemptions vaccine mandate put unpaid leave remind',
#  'telling flight attendants duct tape unruly passengers get assoc',
#  'telling flight attendants duct tape unruly passengers via fox news',
#  'telling flight attendants duct tape unruly passengers via fox news',
#  'tells employees duct tape unruly passengers headline ever expected read',
#  'tells flight crews avoid duct tape actual chyron evening news surreal',
#  'fire workers refused get vaccination coral murphy marcos via nyt',
#  'fire workers refused get vaccination coral murphy marcos via nyt',
#  'fire workers refused get vaccination coral murphy marcos via nyt',
#  'warns flight attendants duct tape unruly passengers agree waste perfectly go',
#  'require employees vaccinated coronavirus first major airline',
#  'require us employees get vaccinated covid later oct',
#  'require us employees get vaccinated happens antibodydepen',
#  'united asks flight attendants tape passengers seats heather murphy',
#  'united asks flight attendants tape passengers seats heather murphy nyt newyorktimes',
#  'united asks flight attendants tape passengers seats heather murphy via nyt read',
#  'united asks flight attendants tape passengers seats heather murphy via nyt',
#  'united asks flight attendants tape passengers seats heather murphy via nyt',
#  'united asks flight attendants tape passengers seats heather murphy via nyt',
#  'united asks flight attendants tape passengers seats heather murphy via nyt',
#  'united asks flight attendants tape passengers seats heather murphy via nyt',
#  'united asks flight attendants tape passengers seats heather murphy via nyt nyt usa news',
#  'united asks flight attendants tape passengers seats heather murphy via nyt',
#  'united asks flight attendants tape passengers seats heather murphy via nyt',
#  'united asks flight attendants tape passengers seats via trending news',
#  'united ceo im tired employees dying much preferred headline email got read',
#  'united first us airline mandate vaccines employees read',
#  'united friday became first major us airline require employees get vaccinated enough',
#  'uniteds draconian vaccine mandate rejects free market principles cpac warns conservative political actio',
#  'unruly passenger growls flight crew shouts joe biden really',
#  'unruly passenger growls flight crew shouts joe biden really via fox news',
#  'unvaccinated air lines employees soon forced pay additional per monthmaking gaba',
#  'vaccinations safest effective powerful tool achieve goals live v',
#  'vaccine requirements work says usbased employees fully vaccinated',
#  'viasatequipped jets offer free access tiktok promotional offering limited minutes',
#  'proud girl arrived back home texas heros welcome via',
#  'help create safe environment crew customers onboard aircraft ai',
#  'help create safe environment crew customers onboard aircraft ai',
#  'losing employees per week losing lives covid unvaccinated havent',
#  'cannot solve climate change unless stop deforestation cannot stop deforestation without accelerated',
#  'certainly encourage everywhere encourage customers employees putti',
#  'concluded enough enough people dying something stop inside decision',
#  'could glue face',
#  'dont talk enough deforestation amelia deluca says corpgov saying need fix f',
#  'strategic plan called things herb kelleher cofounder weeks prod',
#  'strategic plan called things herb kelleher cofounder',
#  'hope providing employees volunteer opportunities throughout september channel',
#  'knew successful would suicide mission would coming home told',
#  'knew successful would suicide mission would coming home told',
#  'know disagree decision require vaccine united employees fact',
#  'know disagree decision require vaccine united employees ceo scott k',
#  'know disagree decision require vaccine united employees airline',
#  'stop fiddling around edges get vaccinated put behind us united airlin',
#  'understand frustrating guests plans change unexpectedly',
#  'going change way name covid variants dont engender prejudice certain people',
#  'seeing strong movement early action toward vaccine requirements across industries importantly th',
#  'well sir dont make final destination bag wont either said know wh',
#  'well wrong prove entirely procompetitive ceo doug parker tel',
#  'telling team please get vaccinated end month get incentives befo',
#  'texas lawmakers advanced restrictive voting rights bill year technologies two',
#  'tyranny calls answers dont care science viruses people flying profit',
#  'youre youre danger crew love pilot',
#  'route network reflects mainline carrier customerunfriendly focus c',
#  'michael oleary fired veiled warning shot boeing yesterday noting airlines including delta jet',
#  'wild brawl breaks flight austin new orleans video',
#  'billion annual revenue nothing lose father lastditch effo',
#  'rhetoric ramping becoming increasingly clear early decisive move united require vac',
#  'rise variant',
#  'yeah im member milehigh club guy jerked bathroom flight',
#  'yeah im happy ourgovernment threats worked ceo firing hundreds unvaccinated workers',
#  'yes zulu golf alfa xray tango quebec v proud calling abl',
#  'yesterday biden administration federal workers pentagon expected follow',
#  'yesterday employee die spent eight days emergency room waiting',
#  'fired arent paying anymore',
#  'choose seeing world saving world amelia deluca says',
#  'dont know deal dont judge responded saying job example',
#  'either wait us get airplanecpt trippin aaflight dfw mtb jamaica delays neveragain',
#  'go hell customer service mondayactionmovie',
#  'hear loud antivax voice lot hear people want sad much bent',
#  'shouldve waiting gate regardless whether theres delay thank unhelpful customer service ag',
#  'get voucher land charlotte people waiting line thank',
#  'youre fired dont work dont pay hope trend takes covid doesnt give da',
#  'current wait time approximately hours minutes callback feature really stars',
#  'estimated wait time less hours really wait close hours make change reservation',
#  'delta air lines inc require unvaccinated employees pay extra month company healt',
#  'airports trying ease psychic turbulence ground writes new york times timely piece',
#  'ad tickets dua lipa center dallas tx',
#  'ad tickets elton john center dallas tx',
#  'ad tickets elton john center dallas tx',
#  'ad tickets shawn mendes center dallas tx',
#  'ad tickets shawn mendes center dallas tx',
#  'ad fantasy flight luggage name tag',
#  'life fucking nightmare mulaney john',
#  'drinking water safe great swb setting filling stations neighboring parishes without drinking wa',
#  'ladies gentlemen anyone lose okay ive got attention wed like go saf',
#  'us simply try figure says howard putnam former ceo g',
#  'remember years back club orlando hot dogs dont kno',
#  'thank diamond medallion member gate agent',
#  'taliban taken civilian side airport ill honest would definitely fly taliban',
#  'whole employee deficit nicely demonstrates airlines pocketed us taxpayer money intended used',
#  'reminds flight crews restrain unruly passengers duct tape',
#  'following orders th century slave hunters william calley lai fucking gross',
#  'violates civil rights act employees sue companys covid vaccine mandate',
#  'broke internet major outages hit bank america zoom snapchat others fb',
#  'thhour thank fire us employees meet september th deadline',
#  'thhour thank fire us employees meet september th deadli',
#  'yearanniversary trip booked kimi excited go back favorite city celebr',
#  'important isnt american asking passengers test covad test suppling mask sale',
#  'many employees wearing masks correctly wear',
#  'august th held surprise exercise headquarters chicago simulating',
#  'another quote empowering leader weve never thought come work assu',
#  'k h rn na takes reno international airport bound las vegas',
#  'mike busch aircraft maintenance also calling civil reserve air fleet united ai',
#  'trip report interview pilot bonuses faa zerotolerance policy',
#  'steve hinton air museum also contract sustainable aviation fuel r',
#  'max test frame flight line n',
#  'daystogoforavatarandiwas god incarnates four ages present time incarnated fo',
#  'ad n boeing away heading e mih',
#  'fuselage degradation easa airbus airports',
#  'acb nan boeing er away heading e mih',
#  'values childrens safety health im cause dont want travel tooyoun',
#  'flight staff clue get back dc cared abou',
#  'aab nan boeing er away heading e mih',
#  'tradingview',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nar boeing er away heading w mih',
#  'nar boeing er away heading w mih',
#  'nat boeing er away heading w mih',
#  'nat boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading nw mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading e mih',
#  'nan boeing er away heading nw mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nal boeing away heading se mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er km away horizon heading se',
#  'nan boeing er away heading e mih',
#  'nan boeing er km away horizon heading se',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nar boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er km away horizon heading w',
#  'miami san juan nan boeing km radar altitude',
#  'nan boeing er away heading e mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'naj boeing er away heading w mih',
#  'naj boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing away heading e mih',
#  'nan boeing away heading w mih',
#  'naa boeing km away horizon heading w kmh',
#  'nan boeing km away horizon heading e kp',
#  'naa boeing km away horizon heading e kp',
#  'nan boeing km away horizon heading e kp',
#  'nan boeing km away horizon heading e kp',
#  'nay boeing km away horizon heading e kp',
#  'naa boeing km away horizon heading e kp',
#  'nan boeing km away horizon heading e kp',
#  'naa boeing km away horizon heading e kp',
#  'naa boeing km away horizon heading e kp',
#  'nan boeing km away horizon heading e kp',
#  'naa boeing km away horizon heading e kp',
#  'nan boeing er away heading se',
#  'nan boeing er km away horizon heading se',
#  'nan boeing away heading e mih',
#  'nan boeing away heading se mih',
#  'nan boeing km away horizon heading se kmh',
#  'nan boeing er away heading e mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nat boeing er away heading ne mih',
#  'nan boeing er away heading se',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nar boeing er away heading w mih',
#  'nar boeing er away heading w mih',
#  'nar boeing er away heading w mih',
#  'nat boeing er away heading w mih',
#  'nat boeing er away heading w mih',
#  'nat boeing er away heading w mih',
#  'nat boeing er away heading w mih',
#  'nat boeing er away heading w mih',
#  'nat boeing er away heading w mih',
#  'nal boeing away heading e mih',
#  'nal boeing away heading e mih',
#  'nal boeing away heading e mih',
#  'nal boeing away heading e mih',
#  'nan boeing away heading e mih',
#  'naa boeing away heading e mih',
#  'nan boeing away heading e mih',
#  'nan boeing away heading e mih',
#  'nan boeing away heading e mih',
#  'nan boeing away heading e mih',
#  'nan boeing away heading e mih',
#  'nan boeing away heading e mih',
#  'nan boeing away heading e mih',
#  'nan boeing away heading e mih',
#  'nan boeing away heading e mih',
#  'dallasfort worth frankfurt nan boeing dreamliner km',
#  'dallasfort worth frankfurt nan boeing dreamliner km',
#  'nax boeing away heading se mih',
#  'nan boeing er away heading w mih',
#  'nam boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading nw mih',
#  'nan boeing er away heading w mih',
#  'naj boeing er away heading nw mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'naj boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nan boeing er away heading w mih',
#  'nbb boeing away heading e mih',
#  'nan boeing away heading w mih',
#  'nan boeing away heading w mih',
#  'nan boeing away heading nw mih',
#  'naa boeing away heading w mih',
# ...
#  'africantourismboard airlines airport aviation southern africa flights airlink thi',
#  'airtravel unitedairlinesholdingsinc anthonyfauci hawaii fda vaccine mandates travel legal',
#  'airforwarders platinum member cargo adds new online booking platform awardwinning cargo',
#  'airlinenews airportnews aviationnews breakingtravelnews nonstop san jos chicago flights return american',
#  'airlinenews airportnews breakingtravelnews businesstravelnews thousands stranded spirit airlines cancels alm',
#  'airlinenews airportnews breakingtravelnews culturaltravelnews working like slave years fired',
#  'airlines airport aviation breakingamericansamoanews flights hawaii american samoa hawaiian airlines',
#  'airlines airport aviation breakinginternationalnews flights bonaire usa delta american uni',
#  'airlines airport aviation breakinginternationalnews official response covid delta hurts air travel recove',
#  'airlines airport aviation breakingtravelnews breakingusnews influencer gab spikes new covi',
#  'airlines airport aviation breakingtravelnews breakingusnews new flights ontario austin southwest ai',
#  'airlines airport aviation breakingtravelnews breakingusnews san jos renotahoe flights southwest airlin',
#  'airlines airport aviation breakingtravelnews breakingusnews announces new president gary k',
#  'airlines aviation breakinginternationalnews breakingtravelnews says jamaicas flight operati',
#  'airlines aviation breakingtravelnews breakingusnews news seriously nice flights breeze airway',
#  'airlines aviation breakingtravelnews news people new covid reality flying us years fe',
#  'airlines breakingnews businesstravel governmentaffairs american spirit happened',
#  'airlines travel transportation aerospaceanddefenseindustry staff granted religious e',
#  'airlines travel transportation aerospaceanddefenseindustry pilots union plan airport pickets',
#  'airlines people unruly many drunk alsoairlines buy booze flights could go wrong',
#  'airlines cutting back flights response covid resurgence heres happening',
#  'airlines cutting back flights response covid resurgence heres happening',
#  'airlines cutting back flights response covid resurgence heres happening',
#  'airlines cutting back flights response covid resurgence heres happening',
#  'airlines cutting back flights response covid resurgence heres happening',
#  'airlines challenges climatechange covid restrictions intl travel weak business travel',
#  'airlines reduced scheduled flights many airports fourth quarter due softer bookings',
#  'airlines reduced scheduled flights many airports fourth quarter due softer bookings',
#  'airlines reduced scheduled flights many airports fourth quarter due softer bookings',
#  'airlines stop ticketed passenger got gate mins prior departure due del',
#  'airlines report must read technical feasibility wheelchair securement concept airline',
#  'airport update teb teterboro nj airport closed due flooding flgihts cancelled toda',
#  'airportsocial happening virtually first exciting panel aviation marketers',
#  'alaskaairlinessucks never gonna fly alaska airlines screwed refused offer',
#  'alexjoneswasright novaxnopay religiouspersecution staff granted religious exemptions',
#  'allstars spoilers love much respect decision wish much success h',
#  'pilots union strike fatigue overscheduling via',
#  'pilots union strike fatigue overscheduling also looking personal assi',
#  'never fly guys missed connection blind traveler perso',
#  'excellent fundamental analysis score fa score check various fa indicators value',
#  'excellent fundamental analysis score fa score check various fa indicators value',
#  'excellent fundamental analysis score fa score check various fa indicators value',
#  'group poor technical analysis score ta score breakdown categories candle',
#  'passenger opened emergency exit walked wing hospitalized sep pm et video',
#  'passenger attempts escape arrest climbing onto plane wing po sep pm et',
#  'pilots union plan airport pickets labor tension fatigue overscheduling heats',
#  'launch miamiseattle service',
#  'microsoft join gatesbacked programme boost clean energy breakingnews news',
#  '',
#  'trying find place rest airport didnt tsa open anywhere due staff',
#  'another delay hours',
#  'american delta say mandate shots',
#  'americanair according www refunds request status check bought ticket related trave',
#  'americanairlines unamerican better type seat gate ive sitting f',
#  'americanairlines flight attendants pilots complain lack hotel rooms transportation',
#  'americanairlines acquire minority stake budgetcarrier jetsmart southamerica part',
#  'americanairlines aateam convention attending got canceled due covid amer',
#  'americanairlines stock price rallies q earnings release',
#  'americanairlines flightattendants pilots complain hotelrooms lack transportation airli',
#  'americanairlines worst gate agent chattanooga airport gate threatened',
#  'americanairlines need pcr go back usa im barcelona',
#  'americanairlines shit customer service called yesterday pm said would call back',
#  'americanairlines thank making wait line hours gate worker answer',
#  'americanairlines disgusting never fly boots baby ha',
#  'americanairlines ceo says biden admin shouldnt require vaccines travel',
#  'americanairlines extends ban alcohol sales economy class midjanuary',
#  'americanairlines flight turned around kicked twoyearold asthmatic boy mother grandm',
#  'americanairlines flight turned around kicked twoyearold asthmatic boy mother grandm',
#  'americanairlines flight turns around kicks mother asthmatic yearold baby mask policy po',
#  'americanairlines possible covid keep money dont let change flight boycott',
#  'americanairlines written haiku poem stranded weary despise',
#  'americanairlines giving passengers free inflight tiktok via',
#  'americanairlines first time flying states definitely satisfying stressful tiring fl',
#  'americanairlines wife trying get home since sat mon flights keep getting cancelled',
#  'americanairlines set reopen industryleading premium flagship lounges',
#  'americanairlines stock shows strength amid market weakness following easing us travel restrictions',
#  'americanairlines strips away flyerprotections changes fineprint',
#  'americanairlines suspends alcohol service next year',
#  'americanairlines youre requiring employees masked vaccinated covid last oct got',
#  'americanairlines acquires gol inaviation avgeek',
#  'americanairlines adds stops tells pilots conserve fuel amid shortage',
#  'americanairlines jetblue face antitrust suit alliance abasal antitrust consumerprotection nytimes',
#  'americanairlines jetblue sued doj airline alliance antitrust lawsuit',
#  'americanairlines jetsmart signed letter intent create joint offering americas',
#  'americanairlines sued usdoj airline alliance',
#  'americanairlines andjetsmart sign letter intent create broadest rewarding network ameri',
#  'americanairlines announces new nonstop flights anguillas clayton j lloyd international airport miami',
#  'americanairlines cancelled flight rescheduled hour connecting flight cancelled fl',
#  'americanairlines cancels flights due pilot shortage saamnews',
#  'americanairlines cancels hundreds flights amid staffing maintenance issues really going',
#  'americanairlines extends ban alcohol sales main cabin passengers via',
#  'americanairlines gave whole line people hotel vouchers hotel rooms waiting lo',
#  'americanairlines making much easier redeem existing travel credits travel via',
#  'americanairlines ready reconnect customers premium dining experience ground reopening',
#  'americanairlines worst whole group flying sent email hours take cancelling',
#  'americanairlines passengers detained fight breaks incident caught video',
#  'americanairlines passengers forced dance boarding deal tiktok via',
#  'americanairlines plans stake south american lowcost carrier jetsmart via businesstraveller',
#  'americanairlines regional piedmontairlines pilots r given bonus minutes',
#  'americanairlines staff use ducttape restrain yearold boy accused trying kick window',
#  'americanairlines stay stranded us dallas without way home',
#  'americanairlines takes tiktok new heights free inflight access customers',
#  'americanairlines webcast remarks raymond james diversified industrials conference',
#  'americanairlines truly annoyed passengers made things worse zdnet',
#  'americanairlines vs united airline stock better investment',
#  'americanairlines heck cancelling flight hours take girls many',
#  'americanairlines extend ban main cabin alcohol sales january travel paxex avgeek',
#  'americanairlines serve alcohol',
#  'americanairlines wont resume alcohol sales economy gaining ground efforts get feder',
#  'americanairlines microsoft join gatesbacked breakthroughenergy program boost cleanenergy',
#  'americanairlinesnazis mother claims turned around flight kicked yearol',
#  'americanairlinesgroupinc frontiergroupholdingsinc delta air lines raising health insurance premiums',
#  'americanairlines one bible one book judas tampa florida tsa going peoples luggage without care wil',
#  'americanairlines southwest delta need job',
#  'anambra okonkwo resigns pdp tipped run zlp chairman united nigeria airlines una chief',
#  'asiacottom yearold trip winning national geographic essay contest dc public school fif',
#  'asianas exit staralliance billion buyout turbocharge southkorean flagcarrier catapult',
#  'atlanta demonstrating different models facilitate entrepreneurialecosystems besides siliconva',
#  'atlanta newyork guyana roundtrip travel janmar dates',
#  'atlanta seattle vice versa roundtrip travel oct dates',
#  'atlanta cozumel mexico roundtrip travel sepoct dates',
#  'atlanta lima peru roundtrip travel oct dates',
#  'atlanta madrid spain roundtrip travel sepmar dates',
#  'atlanta nairobi kenya roundtrip travel sepmar dates',
#  'atlanta tokyo japan roundtrip traveltuesday janapr dates',
#  'atlanta us virgin islands roundtrip travel octnov dates',
#  'austin texas cancun mexico roundtrip travel augnov dates',
#  'austin texas cancun mexico roundtrip travel augnov dates',
#  'austin texas merida mexico roundtrip travel octdec dates',
#  'avgeek dorkfest spotlax crankydorkfest lax losangeles delta getting driving tarmac ne',
#  'avgeeks friday night cocktail week instead two empty glasses remember h',
#  'aviation massive aircraft order solves part uniteds fleetrenewal challenge fleet',
#  'aviation alliance opposed us government',
#  'aviationnews americanairlines philadelphia restart philadelphia flights',
#  'aviationnews americanairlines launches service suriname',
#  'aviationnews hawaiianairlines hawaiian airlines resume american samoa service',
#  'aviationnews united adds flights england',
#  'aviationstl flystl planespotting aviation airport aviationgeek megaaviation airlines aviationlover',
#  'aviationstl flystl planespotting aviation airport aviationgeek megaaviation airlines aviationlover',
#  'aviationstl flystl planespotting aviation airport aviationgeek megaaviation airlines aviationlover',
#  'aviationstl flystl planespotting aviation airport aviationgeek megaaviation airlines aviationlover',
#  'aviationstl flystl planespotting aviation airport aviationgeek megaaviation airlines aviationlover',
#  'aviationstl flystl planespotting aviation airport aviationgeek megaaviation airlines aviationlover',
#  'aviationstl flystl planespotting aviation airport aviationgeek megaaviation airlines aviationlover',
#  'aviationstl flystl planespotting aviation airport aviationgeek megaaviation airlines aviationlover',
#  'aviationstl flystl planespotting aviation airport aviationgeek megaaviation airlines aviationlover',
#  'aviationstl flystl planespotting aviation airport aviationgeek megaaviation airlines aviationlover',
#  'aviationstl flystl planespotting aviation airport aviationgeek megaaviation airlines aviationlover',
#  'aviationstl flystl planespotting aviation airport aviationgeek megaaviation airlines aviationlover',
#  'b non type rated first officers us aviationdaily',
#  'b non type rated first officers us aviationgoals',
#  'bbnaija joins delta nigeriaus routes',
#  'beware major outages hit bank america zoom snapchat come grid going',
#  'bonaire currently november th flying weekly saturday flight bonaire hart',
#  'boycott airlines medicalfreedom informedconsent antimandate novaccinepassports',
#  'boycott delta american providing african migrants free flights us',
#  'boycottdelta cancel bs go ways',
#  'breaking americanairlines responds covid',
#  'breaking doj sues block partnership jetblue us department justice annou',
#  'breaking airlines travel southwest joins others require vaccine employees deadline dec th',
#  'breaking flight miami telaviv make emergency landing israels ben gur',
#  'breaking breakingnews fuse lit biggest companies poppin deltaairlines tells w',
#  'breaking breakingnews fuse lit biggest companies poppin deltaairlines tells wo',
#  'breaking require employees get vaccinated',
#  'breaking announces employees required fully vaccinated covid five',
#  'breaking americans stranded afghanistan say thanks free flight united states spirit airlines',
#  'breaking airbus us atlanta made emergency landing athens greece internati',
#  'breaking tells employees give unruly passengers time new policy supersedes old',
#  'breaking tells employees give unruly passengers time new policy supersedes ol',
#  'breaking us sues block jetblue alliance afp breakingnews',
#  'breaking us sues block jetblue alliance',
#  'breaking us sues block jetblue alliance',
#  'breaking rerouting flights avoid airspace afghanistan',
#  'breaking justice dept states file antitrust challenge jetblue alliance court document jets',
#  'breakingwe remember flight nj sfsep pax includin crew members ga',
#  'breaking briefly stops us canadian flights travel',
#  'breaking require us employees vaccinated covid fall first major',
#  'breaking dfwbased pilots flight attendants staff file federal class action airline offering unpa',
#  'breaking doj sues block jetblue partnership saying reduces competition',
#  'breaking dallas woman sobbed tv accused orchestrating murder exec husban',
#  'breaking miamidade police department says passenger arrested opening',
#  'breaking miamidade police department says passenger arrested opening',
#  'breaking us doj sue challenge partnership according',
#  'breaking us doj sue challenge partnership according',
#  'btnrejects delta american airline impose monthly surcharge nonvaccinated employees uk air',
#  'baltimore indianapolis liberia costa rica roundtrip travel sepmay date',
#  'bantrophyhunting major airlines',
#  'bankruptamericanairlines deserves go worsethanunited americanairlines',
#  'becauseofcovid might wanna rename',
#  'belfast shown gala presentation years london film festival festiva',
#  'berlin germany cancun mexico roundtrip',
#  'biden telling americans hes already moving airlines usa reports saying large groups wi',
#  'bidendisaster biden president usa warns bomb blast kabulaiport afghanishtan treat isis',
#  'bidenregime commie sympathizer want turn america australia airlines may go',
#  'bidenite bribery busted ugandan family caught camera boarding flight id admit',
#  'blooddrives important helps need locally places like wildfir',
#  'bolton boxer amir khan claims hes banned asked leave flight us',
#  'bolton boxer amir khan says hes banned reason removed f',
#  'bolton boxer amir khan says hes banned reason removed f',
#  'boston losangeles vice versa roundtrip travel sepoct dates',
#  'boston sandiego vice versa roundtrip travel octdec dates',
#  'boston sanjose california vice versa roundtrip travel octdec dates',
#  'boston aguadilla puerto rico roundtrip travel sepfeb dates',
#  'boston fairbanks alaska roundtrip travel sep dates',
#  'boston rio de janeiro brazil roundtrip travel sepoct dates',
#  'boston us virgin islands roundtrip travel octnov dates',
#  'boycott dont want need covid flying around must',
#  'boycott discriminating unvaccinated employees ignoring right',
#  'boycott delta southwest',
#  'boycottamericanairlines lets bottom stocks enough bs already',
#  'boycottdelta boycottsouthwest boycottamerican mandate employees passengers',
#  ...]

# %% [markdown]
# Se genera un nuevo dataframe con el contenido limpio

# %%
df_clean = df_raw_no_dup.copy()
df_clean['text'] = corpus_clean

# %% [markdown]
# Debido a la limpieza, es posible que algunos textos que solo contuvieran un usuario, o el usuario y un enlace web, sean ahora textos vacíos, o solo espacios, por lo que es necesario tratarlo. En primer lugar, se convierten los textos que se compongan únicamente de espacios a valores nulos.

# %%
df_clean['text'] = df_clean['text'].replace(r'^\s*$', np.NaN, regex=True)

# %% [markdown]
# Se comprueban ahora los valores nulos y se eliminan.

# %%
df_clean['text'].isnull().sum()
# Out:
# 3949

# %%
df_clean.dropna(inplace=True)

# %% [markdown]
# Se comprueba si existen textos duplicados.

# %%
df_clean['text'].duplicated().sum()
# Out:
# 80625

# %% [markdown]
# Sí que hay textos duplicados. Esto se puede deber a múltiples factores como por ejemplo:
#
# - Textos cuya única diferencia sea el RT al principio del mismo.
# - Textos cuya única diferencia sea la mención a un usuario.
# - Textos que contengan links a noticias de forma que el tweet es el mismo pero con un link diferente.
#
# Todo ello puede hacer que tras la limpieza se encuentren nuevamente textos duplicados y que hay que tratar de la misma manera que anteriormente

# %%
df_clean_no_dup = df_clean.groupby('text').agg({'id': 'first', 
                                            'created_at':'first', 
                                            'retweet_count':'max',
                                            'favorite_count': 'max',
                                            'southwest': 'max',
                                            'american': 'max',
                                            'united': 'max',
                                            'delta': 'max'}).reset_index()

# %% [markdown]
# Se comprueba el nuevo dataframe generado

# %%
df_clean_no_dup['text'].duplicated().sum()
# Out:
# 0

# %%
df_clean_no_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242419 entries, 0 to 242418
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   text            242419 non-null  object
#  1   id              242419 non-null  float64
#  2   created_at      242419 non-null  datetime64[ns]
#  3   retweet_count   242419 non-null  float64
#  4   favorite_count  242419 non-null  float64
#  5   southwest       242419 non-null  float64
#  6   american        242419 non-null  float64
#  7   united          242419 non-null  float64
#  8   delta           242419 non-null  float64
# dtypes: datetime64[ns](1), float64(7), object(1)
# memory usage: 16.6+ MB

# %%
df_clean_no_dup.shape
# Out:
# (242419, 9)

# %% [markdown]
# A continuación, se muestran por pantalla las palabras más y menos comunes del texto para detectar alguna anomalía que se pueda repetir tanto que sea necesario tratarla.

# %%
pd.Series(' '.join(df_clean_no_dup['text']).lower().split()).value_counts()[:50]
# Out:
# flight        39414
# get           15318
# im            12163
# flights       10547
# delta         10255
# us             9989
# time           9250
# hours          9219
# fly            9161
# airlines       9012
# dont           8785
# like           8562
# one            8325
# service        7213
# airline        6927
# people         6842
# flying         6780
# employees      6731
# back           6549
# need           6544
# customer       6151
# would          6108
# plane          6045
# help           6017
# please         5851
# travel         5811
# got            5810
# ive            5653
# still          5639
# covid          5631
# hold           5451
# first          5438
# know           5298
# united         5277
# thank          5231
# going          5199
# never          5152
# thanks         5023
# new            5013
# today          4879
# delayed        4831
# cant           4813
# hour           4662
# airport        4621
# good           4621
# hey            4531
# last           4411
# vaccinated     4370
# go             4275
# make           4083
# dtype: int64

# %%
pd.Series(' '.join(df_clean['text']).lower().split()).value_counts()[-50:]
# Out:
# rambles                   1
# roadside                  1
# thanksforwastingmytime    1
# bestplacestolive          1
# bestinbiz                 1
# wifisucks                 1
# corbins                   1
# passengerssix             1
# sundayampleft             1
# nervou                    1
# dtr                       1
# wordi                     1
# maskupforskyjuice         1
# gateterminal              1
# mixrace                   1
# goingi                    1
# gracies                   1
# msybwi                    1
# delayswhat                1
# tyran                     1
# flightsmsp                1
# unpleased                 1
# ishouldhavedrove          1
# nondire                   1
# lgamdw                    1
# capitulate                1
# maitre                    1
# jetwaygeez                1
# undermanned               1
# hotelresort               1
# ims                       1
# flyingtocalifornia        1
# requesti                  1
# mdwcun                    1
# hoursdays                 1
# listers                   1
# expiratio                 1
# halfmarathon              1
# needrepresenative         1
# phoneissues               1
# techical                  1
# vei                       1
# encounterednot            1
# thao                      1
# baggagethe                1
# nolo                      1
# toohow                    1
# imalittlepushy            1
# answersuper               1
# hyperve                   1
# dtype: int64

# %% [markdown]
# Analizando las palabras más comunes, no hay ningún término que llame la atención, lo cuál podría significar algún tipo de fallo a la hora de preprocesar el texto, por lo que es una buena señal el resultado obtenido.
#
# En cuanto a las palabras menos comunes, se puede observar que muchas de ellas son fallos a la hora de escribir los vocablos, por lo que podrían ser eliminados, pero no se considera necesario, y se decide no modificar el texto.

# %%
df_clean_no_dup.to_csv("df_sentiment_clean_no_dup.csv", sep = ',', index=False, 
              columns = ['id','created_at','text','retweet_count','favorite_count', 
                         'southwest', 'american', 'united', 'delta'])
